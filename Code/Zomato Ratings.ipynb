# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\naman\Downloads\archive (9)\zomato.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           15.033741
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.drop(columns=['url','address','phone','reviews_list','menu_item','name'],inplace=True)

# %%
df.head()
# Out:
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people) listed_in(type)  \
# 0  North Indian, Mughlai, Chinese                         800          Buffet
# ...

# %%
df.shape
# Out:
# (51717, 11)

# %%
df.duplicated().sum()
# Out:
# 371

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (51346, 11)

# %%
df['online_order'].value_counts()
# Out:
# Yes    30315
# No     21031
# Name: online_order, dtype: int64

# %%
df['rate']=df['rate'].str.replace("/5","")
df['rate']
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 51712    3.6
# 51713     NaN
# 51714     NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51346, dtype: object

# %%
df['votes']=df['votes'].astype('int32')

# %%
df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', nan, 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Sarjapur Road', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Whitefield', 'East Bangalore', 'Old Airport Road',
#        'Indiranagar', 'Koramangala 1st Block', 'Frazer Town', 'RT Nagar',
#        'MG Road', 'Brigade Road', 'Lavelle Road', 'Church Street',
#        'Ulsoor', 'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road',
# ...

# %%
df.drop(columns="location",inplace=True)

# %%
df.head()
# Out:
#   online_order book_table rate  votes            rest_type  \
# 0          Yes        Yes  4.1    775        Casual Dining
# 1          Yes         No  4.1    787        Casual Dining
# 2          Yes         No  3.8    918  Cafe, Casual Dining
# 3           No         No  3.7     88          Quick Bites
# 4           No         No  3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people) listed_in(type)  \
# 0  North Indian, Mughlai, Chinese                         800          Buffet
# 1     Chinese, North Indian, Thai                         800          Buffet
# ...

# %%
df=df.rename(columns={"approx_cost(for two people)":"avg_cost","listed_in(type)":"type","listed_in(city)":"city"})

# %%
df.head()
# Out:
#   online_order book_table rate  votes            rest_type  \
# 0          Yes        Yes  4.1    775        Casual Dining
# 1          Yes         No  4.1    787        Casual Dining
# 2          Yes         No  3.8    918  Cafe, Casual Dining
# 3           No         No  3.7     88          Quick Bites
# 4           No         No  3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines avg_cost    type          city
# 0  North Indian, Mughlai, Chinese      800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai      800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian      800  Buffet  Banashankari
# ...

# %%
df['city'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# online_order     0.000000
# book_table       0.000000
# rate            14.645737
# votes            0.000000
# rest_type        0.438204
# dish_liked      54.047053
# cuisines         0.083746
# avg_cost         0.664122
# type             0.000000
# city             0.000000
# dtype: float64

# %%
df.dropna(subset=['rest_type','cuisines','avg_cost'],inplace=True)

# %%
df.shape
# Out:
# (50782, 10)

# %%
df['online_order'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
list(df['rate'].unique())
# Out:
# ['4.1',
#  '3.8',
#  '3.7',
#  '3.6',
#  '4.6',
#  '4.0',
#  '4.2',
#  '3.9',
#  '3.1',
#  '3.0',
#  '3.2',
#  '3.3',
#  '2.8',
#  '4.4',
#  '4.3',
#  'NEW',
#  '2.9',
#  '3.5',
#  nan,
#  '2.6',
#  '3.8 ',
#  '3.4',
#  '4.5',
#  '2.5',
#  '2.7',
#  '4.7',
#  '2.4',
#  '2.2',
#  '2.3',
#  '3.4 ',
#  '-',
#  '3.6 ',
#  '4.8',
#  '3.9 ',
#  '4.2 ',
#  '4.0 ',
#  '4.1 ',
#  '3.7 ',
#  '3.1 ',
#  '2.9 ',
#  '3.3 ',
#  '2.8 ',
#  '3.5 ',
#  '2.7 ',
#  '2.5 ',
#  '3.2 ',
#  '2.6 ',
#  '4.5 ',
#  '4.3 ',
#  '4.4 ',
#  '4.9',
#  '2.1',
#  '2.0',
#  '1.8',
#  '4.6 ',
#  '4.9 ',
#  '3.0 ',
#  '4.8 ',
#  '2.3 ',
#  '4.7 ',
#  '2.4 ',
#  '2.1 ',
#  '2.2 ',
#  '2.0 ',
#  '1.8 ']

# %%
df['rate']=df['rate'].str.replace(" ","")

# %%
df['rate']=df['rate'].replace(to_replace=["-"," nan"],value="NaN")

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5', nan,
#        '2.6', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3',
#        'NaN', '4.8', '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df['rate']=df['rate'].fillna("NaN")

# %%
df['dish_liked'].unique()
# Out:
# array(['Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#        'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#        'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#        ...,
#        'Noodles, Chicken Noodle, Momos, American Chopsuey, Salad, Manchow Soup, Manchurian',
#        'Chicken Quesadilla, Naan, Breakfast Buffet, Cheesecake, Cocktails, Lunch Buffet, Biryani',
#        'Biryani, Andhra Meal'], dtype=object)

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5',
#        'NaN', '2.6', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '4.8', '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df['rate'].value_counts()
# Out:
# NaN    7427
# 3.9    3953
# 3.8    3816
# 3.7    3801
# 3.6    3280
# 4.0    3142
# 4.1    2922
# 3.5    2761
# 3.4    2443
# 3.3    2272
# NEW    2169
# 4.2    2151
# 3.2    1838
# 4.3    1677
# 3.1    1550
# 4.4    1136
# 3.0     989
# 2.9     800
# 4.5     653
# 2.8     580
# 2.7     303
# 4.6     299
# 2.6     249
# 4.7     167
# 2.5     100
# 2.4      66
# 4.8      66
# 4.9      55
# 2.3      51
# 2.2      26
# 2.1      24
# 2.0      11
# 1.8       5
# Name: rate, dtype: int64

# %%
df['rate']=df['rate'].replace("NEW","0.0")

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '0.0', '2.9', '3.5',
#        'NaN', '2.6', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '4.8', '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df.isnull().sum()
# Out:
# online_order        0
# book_table          0
# rate                0
# votes               0
# rest_type           0
# dish_liked      27389
# cuisines            0
# avg_cost            0
# type                0
# city                0
# dtype: int64

# %%
sns.countplot(df['online_order'])

# %%
df.head()
# Out:
#   online_order book_table rate  votes            rest_type  \
# 0          Yes        Yes  4.1    775        Casual Dining
# 1          Yes         No  4.1    787        Casual Dining
# 2          Yes         No  3.8    918  Cafe, Casual Dining
# 3           No         No  3.7     88          Quick Bites
# 4           No         No  3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines avg_cost    type          city
# 0  North Indian, Mughlai, Chinese      800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai      800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian      800  Buffet  Banashankari
# ...

# %%
sns.countplot(df['book_table'])

# %%
plt.figure(figsize=(18,16))
plt.pie(df['rest_type'].value_counts()[:10],labels=df['rest_type'].value_counts().index[:10],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x210817565b0>,
# ...
#  [Text(0.22710074488889562, 1.0763016545889488, 'Quick Bites'),
#   Text(-1.0415547890273271, -0.3537847105998793, 'Casual Dining'),
#   Text(-0.25402821778463186, -1.07026616529215, 'Cafe'),
#   Text(0.2391042941054133, -1.0736988109057177, 'Delivery'),
#   Text(0.5904164675347001, -0.928120894530366, 'Dessert Parlor'),
#   Text(0.8436960165019627, -0.705816570887026, 'Takeaway, Delivery'),
#   Text(0.9810179581222589, -0.4975979962194726, 'Casual Dining, Bar'),
#   Text(1.0488832129862147, -0.33142722506715566, 'Bakery'),
#   Text(1.0855878041641698, -0.17747991280710182, 'Beverage Shop'),
#   Text(1.0986395402073943, -0.05469150475974962, 'Bar')],
#  [Text(0.12387313357576123, 0.5870736297757903, '43.38'),
#   Text(-0.5681207940149057, -0.19297347850902505, '23.66'),
#   Text(-0.13856084606434463, -0.583781544704809, '8.50'),
#   Text(0.13042052405749816, -0.5856538968576642, '5.89'),
# ...

# %%
df['rest_type'].value_counts().index
# Out:
# Index(['Quick Bites', 'Casual Dining', 'Cafe', 'Delivery', 'Dessert Parlor',
#        'Takeaway, Delivery', 'Casual Dining, Bar', 'Bakery', 'Beverage Shop',
#        'Bar', 'Food Court', 'Sweet Shop', 'Bar, Casual Dining', 'Lounge',
#        'Pub', 'Fine Dining', 'Casual Dining, Cafe',
#        'Beverage Shop, Quick Bites', 'Bakery, Quick Bites', 'Mess',
#        'Pub, Casual Dining', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Dessert Parlor, Cafe', 'Cafe, Casual Dining', 'Cafe, Bakery',
#        'Cafe, Dessert Parlor', 'Bakery, Dessert Parlor',
#        'Microbrewery, Casual Dining', 'Casual Dining, Pub',
#        'Dessert Parlor, Quick Bites', 'Takeaway', 'Cafe, Quick Bites',
#        'Quick Bites, Beverage Shop', 'Food Court, Quick Bites',
#        'Dessert Parlor, Bakery', 'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Pub, Microbrewery', 'Dessert Parlor, Beverage Shop',
#        'Beverage Shop, Dessert Parlor', 'Bakery, Cafe',
# ...

# %%
plt.pie(df['cuisines'].value_counts(),labels=df['cuisines'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x210817c7e80>,
# ...
#   ...],
#  [Text(1.0837021731046557, 0.18865206070501095, 'North Indian'),
#   Text(0.9712238905898208, 0.5164534387024371, 'North Indian, Chinese'),
#   Text(0.8116114023985999, 0.7424869907928207, 'South Indian'),
#   Text(0.6805663681735706, 0.8641929289869457, 'Biryani'),
#   Text(0.5824545582068515, 0.9331380860430365, 'Bakery, Desserts'),
#   Text(0.4833591545023886, 0.9881112932047362, 'Fast Food'),
#   Text(0.38742594136818864, 1.029515002297185, 'Desserts'),
#   Text(0.29193573303197223, 1.0605534063775786, 'Cafe'),
#   Text(0.1961562102839036, 1.0823690411163178, 'South Indian, North Indian, Chinese'),
#   Text(0.10396219542033538, 1.0950761900084323, 'Bakery'),
#   Text(0.022795342985782834, 1.0997637802447218, 'Chinese'),
#   Text(-0.04258912571285026, 1.0991752209593406, 'Ice Cream, Desserts'),
#   Text(-0.09827018173786611, 1.0956016481281903, 'Chinese, North Indian'),
# ...

# %%
ax=df['cuisines'].value_counts()[:10]
ax.plot(kind='bar')

# %%
df['type'].value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(15,15))
plt.pie(df['city'].value_counts(),labels=df['city'].value_counts().index,autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x21092dcda90>,
# ...
#  [Text(1.0782201198054644, 0.21781040665379248, 'BTM'),
#   Text(0.9216483366346875, 0.6004701021520672, 'Koramangala 7th Block'),
#   Text(0.6587571502849366, 0.8809307673980229, 'Koramangala 5th Block'),
#   Text(0.32544123167229355, 1.0507559206245858, 'Koramangala 4th Block'),
#   Text(-0.0314351494059791, 1.0995507407035947, 'Koramangala 6th Block'),
#   Text(-0.3599696206611786, 1.0394334380810766, 'Jayanagar'),
#   Text(-0.6268987287853449, 0.9038794078013498, 'JP Nagar'),
#   Text(-0.8244855086230165, 0.7281645734795439, 'Indiranagar'),
#   Text(-0.965249648119855, 0.5275349436809814, 'Church Street'),
#   Text(-1.057142834655064, 0.30405431609739786, 'MG Road'),
#   Text(-1.097954203988916, 0.0670564384907672, 'Brigade Road'),
#   Text(-1.0869330595007567, -0.16904592324077136, 'HSR'),
#   Text(-1.0269522946015466, -0.3941687260712329, 'Lavelle Road'),
#   Text(-0.9250141563212874, -0.5952720475591116, 'Marathahalli'),
# ...

# %%
ax=df['dish_liked'].value_counts()[:12]
ax.plot(kind='bar')

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=df['rate'],hue=df['online_order'])

# %%
df.head()
# Out:
#   online_order book_table rate  votes            rest_type  \
# 0          Yes        Yes  4.1    775        Casual Dining
# 1          Yes         No  4.1    787        Casual Dining
# 2          Yes         No  3.8    918  Cafe, Casual Dining
# 3           No         No  3.7     88          Quick Bites
# 4           No         No  3.8    166        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines avg_cost    type          city
# 0  North Indian, Mughlai, Chinese      800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai      800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian      800  Buffet  Banashankari
# ...

# %%
df.drop(columns='dish_liked',inplace=True)

# %%
df.head()
# Out:
#   online_order book_table rate  votes            rest_type  \
# 0          Yes        Yes  4.1    775        Casual Dining
# 1          Yes         No  4.1    787        Casual Dining
# 2          Yes         No  3.8    918  Cafe, Casual Dining
# 3           No         No  3.7     88          Quick Bites
# 4           No         No  3.8    166        Casual Dining
#
#                          cuisines avg_cost    type          city
# 0  North Indian, Mughlai, Chinese      800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai      800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian      800  Buffet  Banashankari
# 3      South Indian, North Indian      300  Buffet  Banashankari
# 4        North Indian, Rajasthani      600  Buffet  Banashankari

# %%
df.dropna(how='any',inplace=True)
df.isnull().sum()
# Out:
# online_order    0
# book_table      0
# votes           0
# rest_type       0
# cuisines        0
# avg_cost        0
# type            0
# city            0
# rate            0
# dtype: int64

# %%
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
col=[c for c in df.columns if df[c].dtypes=='O']

# %%
df.shape
# Out:
# (43355, 9)

# %%
df.head()
# Out:
#    online_order  book_table  votes  rest_type  cuisines  avg_cost  type  city  \
# 0             1           1    767         27      2145        66     0     1
# 1             1           0    778         27       947        66     0     1
# 2             1           0    887         22       761        66     0     1
# 3             0           0     87         78      2539        42     0     1
# 4             0           0    165         27      2174        60     0     1
#
#    rate
# 0   4.1
# 1   4.1
# 2   3.8
# 3   3.7
# 4   3.8

# %%
df['rate']=df['rate'].astype(float)
df['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 43355, dtype: float64

# %%
col=[c for c in df.columns if df[c].dtypes=='O']
df.columns
# Out:
# Index(['online_order', 'book_table', 'votes', 'rest_type', 'cuisines',
#        'avg_cost', 'type', 'city', 'rate'],
#       dtype='object')

# %%
df=df[['online_order', 'book_table','votes', 'rest_type', 'cuisines',
       'avg_cost', 'type', 'city','rate']]
x=df.iloc[:,:-1]
y=df.iloc[:,-1].values
x.columns
# Out:
# Index(['online_order', 'book_table', 'votes', 'rest_type', 'cuisines',
#        'avg_cost', 'type', 'city'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 43355, dtype: float64

# %%
col=['online_order', 'book_table','votes', 'rest_type', 'cuisines',
       'avg_cost', 'type','city']
for i in col:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    online_order  book_table  votes  rest_type  cuisines  avg_cost  type  city  \
# 0             1           1    767         24      1981        61     0     1
# 1             1           0    778         24       855        61     0     1
# 2             1           0    887         19       685        61     0     1
# 3             0           0     87         73      2327        40     0     1
# 4             0           0    165         24      2010        55     0     1
#
#    rate
# 0   4.1
# 1   4.1
# 2   3.8
# 3   3.7
# 4   3.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43355 entries, 0 to 51716
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   online_order  43355 non-null  int64
#  1   book_table    43355 non-null  int64
#  2   votes         43355 non-null  int64
#  3   rest_type     43355 non-null  int64
#  4   cuisines      43355 non-null  int64
#  5   avg_cost      43355 non-null  int64
#  6   type          43355 non-null  int64
#  7   city          43355 non-null  int64
#  8   rate          43355 non-null  float64
# dtypes: float64(1), int64(8)
# memory usage: 3.3 MB

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1].values

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
rfe=RandomForestRegressor()

# %%
df.loc[df['rate']!="nan"]
# Out:
# C:\Users\naman\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#        online_order  book_table  votes  rest_type  cuisines  avg_cost  type  \
# 0                 1           1    767         24      1981        61     0
# 1                 1           0    778         24       855        61     0
# 2                 1           0    887         19       685        61     0
# 3                 0           0     87         73      2327        40     0
# 4                 0           0    165         24      2010        55     0
# ...             ...         ...    ...        ...       ...       ...   ...
# 51709             0           0     33         25      1868        61     6
# 51711             0           0     80         25       104        61     6
# ...

# %%
rfe.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import r2_score
print(rfe.score(x_test,y_test))
# Out:
# 0.9717489939619331

# %%
pred=rfe.predict(x_test)

# %%
acc=r2_score(y_test,pred)
print(acc)
# Out:
# 0.9717489939619331

# %%
import pickle

# %%
pickle.dump(rfe,open('zomato.pkl','wb'))

# %%
model=pickle.load(open('zomato.pkl','rb'))

# %%
model.predict(x_test)
# Out:
# array([3.018, 3.453, 3.895, ..., 3.293, 3.437, 3.567])
